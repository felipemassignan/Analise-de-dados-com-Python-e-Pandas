# %%
import pandas as pd

# %%
import pandas as pd

# %%
df1=pd.read_excel('/content/drive/MyDrive/Curso_Python_Pandas/datasets/Aracaju.xlsx')
df2=pd.read_excel('/content/drive/MyDrive/Curso_Python_Pandas/datasets/Fortaleza.xlsx')
df3=pd.read_excel('/content/drive/MyDrive/Curso_Python_Pandas/datasets/Natal.xlsx')
df4=pd.read_excel('/content/drive/MyDrive/Curso_Python_Pandas/datasets/Recife.xlsx')
df5=pd.read_excel('/content/drive/MyDrive/Curso_Python_Pandas/datasets/Salvador.xlsx')

# %%
df1.head()
# Out:
#     Cidade       Data  Vendas  LojaID  Qtde
# 0  Aracaju 2018-01-01  142.00    1520     1
# 1  Aracaju 2018-01-01   14.21    1522     6
# 2  Aracaju 2018-01-01   71.55    1520     1
# 3  Aracaju 2018-01-01    3.01    1521     7
# 4  Aracaju 2018-01-01   24.51    1522     8

# %%
df = pd.concat([df1,df2,df3,df4,df5])

# %%
df.head()
# Out:
#     Cidade       Data  Vendas  LojaID  Qtde
# 0  Aracaju 2018-01-01  142.00    1520     1
# 1  Aracaju 2018-01-01   14.21    1522     6
# 2  Aracaju 2018-01-01   71.55    1520     1
# 3  Aracaju 2018-01-01    3.01    1521     7
# 4  Aracaju 2018-01-01   24.51    1522     8

# %%
df.tail()
# Out:
#        Cidade       Data  Vendas  LojaID  Qtde
# 235  Salvador 2019-01-03   41.84    1034     1
# 236  Salvador 2019-01-03  126.29    1035     3
# 237  Salvador 2019-01-03   38.06    1036     3
# 238  Salvador 2019-01-03  139.64    1035     1
# 239  Salvador 2019-01-03  161.41    1037     3

# %%
df.sample(5)
# Out:
#        Cidade       Data  Vendas  LojaID  Qtde
# 134     Natal 2019-01-02  125.90    1036     1
# 136    Recife 2019-03-02   39.09     982     4
# 105     Natal 2019-01-02   32.83    1037     1
# 213  Salvador 2019-01-02   42.12    1035     1
# 152     Natal 2019-01-02   20.07    1035     1

# %%
df.dtypes
# Out:
# Cidade            object
# Data      datetime64[ns]
# Vendas           float64
# LojaID             int64
# Qtde               int64
# dtype: object

# %%
df['LojaID'] = df['LojaID'].astype("object")

# %%
df.dtypes
# Out:
# Cidade            object
# Data      datetime64[ns]
# Vendas           float64
# LojaID            object
# Qtde               int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Cidade    0
# Data      0
# Vendas    0
# LojaID    0
# Qtde      0
# dtype: int64

# %%
df["Receitas"] = df['Vendas'].mul(df['Qtde'])

# %%
df.head()
# Out:
#     Cidade       Data  Vendas LojaID  Qtde  Receitas
# 0  Aracaju 2018-01-01  142.00   1520     1    142.00
# 1  Aracaju 2018-01-01   14.21   1522     6     85.26
# 2  Aracaju 2018-01-01   71.55   1520     1     71.55
# 3  Aracaju 2018-01-01    3.01   1521     7     21.07
# 4  Aracaju 2018-01-01   24.51   1522     8    196.08

# %%
df['Receitas'].max()
# Out:
# 3544.0

# %%
df['Receitas'].min()
# Out:
# 3.34

# %%
df.nlargest(5,'Receitas')
# Out:
#    Cidade       Data  Vendas LojaID  Qtde  Receitas
# 7   Natal 2019-03-18   886.0    853     4    3544.0
# 51  Natal 2018-01-21   859.0    852     4    3436.0
# 55  Natal 2019-01-08   859.0    854     4    3436.0
# 30  Natal 2018-10-02   856.0    853     4    3424.0
# 41  Natal 2018-05-20   835.0    852     4    3340.0

# %%
df.nsmallest(5,'Receitas')
# Out:
#        Cidade       Data  Vendas LojaID  Qtde  Receitas
# 118   Aracaju 2018-01-01    3.34   1522     1      3.34
# 65     Recife 2019-01-01    4.01    981     1      4.01
# 92      Natal 2019-01-02    4.57   1035     1      4.57
# 92   Salvador 2019-01-01    4.57   1035     1      4.57
# 95      Natal 2019-01-02    5.13   1035     1      5.13

# %%
df.groupby('Cidade')['Receitas'].sum()
# Out:
# Cidade
# Aracaju       48748.25
# Fortaleza     37913.97
# Natal        167227.52
# Recife        51936.51
# Salvador      40596.73
# Name: Receitas, dtype: float64

# %%
df.sort_values('Receitas',ascending=False).head(10)
# Out:
#    Cidade       Data  Vendas LojaID  Qtde  Receitas
# 7   Natal 2019-03-18   886.0    853     4    3544.0
# 55  Natal 2019-01-08   859.0    854     4    3436.0
# 51  Natal 2018-01-21   859.0    852     4    3436.0
# 30  Natal 2018-10-02   856.0    853     4    3424.0
# 41  Natal 2018-05-20   835.0    852     4    3340.0
# 38  Natal 2018-02-25   828.0    852     4    3312.0
# 10  Natal 2018-10-27   828.0    852     4    3312.0
# 69  Natal 2019-03-24   817.0    852     4    3268.0
# 62  Natal 2018-02-10   793.0    854     4    3172.0
# 52  Natal 2018-04-27   778.0    854     4    3112.0

# %%
df.dtypes
# Out:
# Cidade              object
# Data        datetime64[ns]
# Vendas             float64
# LojaID              object
# Qtde                 int64
# Receitas           float64
# dtype: object

# %%
df.groupby(df['Data'].dt.year)['Receitas'].sum()
# Out:
# Data
# 2018    118176.53
# 2019    228246.45
# Name: Receitas, dtype: float64

# %%
df['Ano_Venda'] = df['Data'].dt.year

# %%
df.sample(5)
# Out:
#       Cidade       Data  Vendas LojaID  Qtde  Receitas  Ano_Venda
# 4      Natal 2019-03-09  699.00    853     3   2097.00       2019
# 118  Aracaju 2018-01-01    3.34   1522     1      3.34       2018
# 109   Recife 2019-03-02   18.90    982     6    113.40       2019
# 15    Recife 2019-01-01    7.45    981     2     14.90       2019
# 182    Natal 2019-01-02    6.60   1037     2     13.20       2019

# %%
df['Mes_Venda'],df['Dia_Venda'] = (df['Data'].dt.month,df['Data'].dt.day)

# %%
df.sample(5)
# Out:
#        Cidade       Data  Vendas LojaID  Qtde  Receitas  Ano_Venda  Mes_Venda  \
# 29     Recife 2019-01-01   10.18    980     8     81.44       2019          1
# 54   Salvador 2019-01-01   46.54   1037     3    139.62       2019          1
# 124   Aracaju 2018-01-01  139.64   1522     5    698.20       2018          1
# 37      Natal 2018-10-03  726.00    852     2   1452.00       2018         10
# 130    Recife 2019-03-02   12.36    983     4     49.44       2019          3
#
#      Dia_Venda
# 29           1
# 54           1
# 124          1
# 37           3
# 130          2

# %%
df['Diferenca_dias'] = df['Data'] - df['Data'].min()

# %%
df.sample(5)
# Out:
#      Cidade       Data  Vendas LojaID  Qtde  Receitas  Ano_Venda  Mes_Venda  \
# 118  Recife 2019-03-02   17.70    981     5     88.50       2019          3
# 103   Natal 2019-01-02  191.60   1034     1    191.60       2019          1
# 94   Recife 2019-01-01   24.70    982     3     74.10       2019          1
# 236   Natal 2019-01-03  126.29   1035     3    378.87       2019          1
# 51   Recife 2019-01-01  146.95    982     2    293.90       2019          1
#
#      Dia_Venda Diferenca_dias
# 118          2       425 days
# 103          2       366 days
# 94           1       365 days
# 236          3       367 days
# 51           1       365 days

# %%
df['Trimestre_venda'] = df['Data'].dt.quarter

# %%
df.sample(5)
# Out:
#        Cidade       Data  Vendas LojaID  Qtde  Receitas  Ano_Venda  Mes_Venda  \
# 115  Salvador 2019-03-02  202.33   1035     2    404.66       2019          3
# 3       Natal 2019-01-07  271.00    854     3    813.00       2019          1
# 97   Salvador 2019-01-01   39.91   1037     3    119.73       2019          1
# 68      Natal 2018-06-22  274.00    852     3    822.00       2018          6
# 184     Natal 2019-01-02  167.16   1037     1    167.16       2019          1
#
#      Dia_Venda Diferenca_dias  Trimestre_venda
# 115          2       425 days                1
# 3            7       371 days                1
# 97           1       365 days                1
# 68          22       172 days                2
# 184          2       366 days                1

# %%
vendas_marco_2019 = df.loc[(df['Data'].dt.year==2019) & (df['Data'].dt.month==3)]

# %%
vendas_marco_2019.sample(5)
# Out:
#         Cidade       Data  Vendas LojaID  Qtde  Receitas  Ano_Venda  \
# 123   Salvador 2019-03-02  127.45   1036     3    382.35       2019
# 131     Recife 2019-03-02  139.07    982     6    834.42       2019
# 128   Salvador 2019-03-02   36.84   1034     1     36.84       2019
# 136  Fortaleza 2019-03-02   39.09    982     4    156.36       2019
# 120   Salvador 2019-03-02  140.17   1036     2    280.34       2019
#
#      Mes_Venda  Dia_Venda Diferenca_dias  Trimestre_venda
# 123          3          2       425 days                1
# 131          3          2       425 days                1
# 128          3          2       425 days                1
# 136          3          2       425 days                1
# 120          3          2       425 days                1

# %%
df['LojaID'].value_counts(ascending=False)
# Out:
# 1036    117
# 1035    112
# 1037    101
# 1034     67
# 983      65
# 982      44
# 1522     41
# 1520     39
# 980      36
# 981      31
# 1005     30
# 1002     30
# 852      29
# 1523     29
# 1004     28
# 854      28
# 853      26
# 1521     21
# 1003     20
# Name: LojaID, dtype: int64

# %%
df['LojaID'].value_counts(ascending=False).plot.bar()

# %%
df['LojaID'].value_counts(ascending=False).plot.barh()

# %%
df['LojaID'].value_counts(ascending=True).plot.barh()

# %%
df['LojaID'].value_counts(ascending=False).plot.barh();

# %%
df.groupby(df['Data'].dt.year)['Receitas'].sum().plot.pie()

# %%
import matplotlib.pyplot as plt
df['Cidade'].value_counts().plot.bar(title='Total de Vendas por Cidade')
plt.xlabel("Cidade")
plt.ylabel("Total Vendas")
# Out:
# Text(0, 0.5, 'Total Vendas')

# %%
df['Cidade'].value_counts().plot.bar(title='Total de Vendas por Cidade',color="red")
plt.xlabel("Cidade")
plt.ylabel("Total Vendas")
# Out:
# Text(0, 0.5, 'Total Vendas')
